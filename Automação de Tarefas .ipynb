# %% [markdown]
# # Passo a passo do Problema

# %% [markdown]
# -Passo 1: Buscar dados das açoes automaticamente
#
# -Passo 2 : realizar as analises solicitadas pelo meu gestor
#
# -Passo 3 : enviar automaticamente com o resultado da analise

# %% [markdown]
# Buscar dados das açoes automaticamente
# Passo 2 : realizar as analises solicitadas pelo meu gestor
# Passo 3 : enviar automaticamente com o resultado da analise

# %% [markdown]
# # Passo 1

# %%
# !pip install yfinance

# %%
import yfinance as yf
ticker = input("Digite o código da ação: ")
#Buscando no site do yfinance e pegando o historico 
dados = yf.Ticker(ticker).history("6mo")
fechamento = dados.Close
fechamento.plot()
# Out:
# Digite o código da ação: BBAS3.SA
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # PASSO 2 -REALIZAR AS ANÁLISES SOLICITADAS PELO MEU GESTOR
# -Cotação maxima
# -Cotação minima
# -Cotação atual

# %%
maxima = round(fechamento.max(),2)
minima = round(fechamento.min(),2)
atual = round(fechamento[-1],2)

print(maxima)
print(minima)
print(atual)
# Out:
# 44.74
# 30.18
# 44.74

# %% [markdown]
# # PASSO 3:ENVIAR AUTOMATICAMENTE O EMAIL COM O RESULTADO DA ANALISE

# %% [markdown]
# -ABRIR UMA NOVA ABA (CTRL + T)
#
# -DIGITAR WWW.GMAIL.COM
#
# -CLICAR NO BOTÃO ESCREVER
#
# -DIGITAR O DESTINATÁRIO (TAB)
#
# -DIGITAR O ASSUNTO(TAB)
#
# -PREENCHER O CORPO DO EMAIL
#
# -CLICAR NO BOTÃO EMAIL

# %%
# !pip install pyautogui

# %% [markdown]
# !pip install pyperclip

# %%
        
import pyautogui #tudo que for atalho de teclado
import pyperclip

# %%
#dar uma pausa de 2 segundos entre os passos


pyautogui.PAUSE = 5


#-ABRIR UMA NOVA ABA (CTRL + T)
pyautogui.hotkey("ctrl", "t")


#-DIGITAR WWW.GMAIL.COM e dar um enter
pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

#CLICAR NO BOTÃO ESCREVER 
pyautogui.click(x=98, y=177)

#digitar o destinatário (tab)
pyperclip.copy("email@email.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar o assunto
pyperclip.copy("Analises diarias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#preencheer o corpo do email 
mensagem = f"""
Prezado Gestor,

Segume,conforme solicitado ,as análises dos últimos seis meses da ação {ticker}:

Cotação máxima : R$ {maxima}
Cotação minima : R$ {minima}
Cotação atual: R$ {atual}

Qualquer dúvida, fico à disposição !

Att.
Rhuan
"""
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(x=786, y=683)
print("Emaiil enviado com sucesso ")
# Out:
# Emaiil enviado com sucesso

# %%
import time


time.sleep(5)
pyautogui.position()
# Out:
# Point(x=786, y=683)
